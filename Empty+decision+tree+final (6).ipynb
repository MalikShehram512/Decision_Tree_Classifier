# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Decision_Tree_ Dataset.csv')

# %%
df.head()
# Out:
#   Result  Initial Payment  Last Payment  Credit Score  House Number
# 0    yes              201         10018           250          3046
# 1    yes              205         10016           395          3044
# 2    yes              257         10129           109          3251
# 3    yes              246         10064           324          3137
# 4    yes              117         10115           496          3094

# %%
df.info
# Out:
# <bound method DataFrame.info of     Result  Initial Payment  Last Payment  Credit Score  House Number
# 0      yes              201         10018           250          3046
# 1      yes              205         10016           395          3044
# 2      yes              257         10129           109          3251
# 3      yes              246         10064           324          3137
# 4      yes              117         10115           496          3094
# ..     ...              ...           ...           ...           ...
# 995     No              413         14914           523          4683
# 996     No              359         14423           927          4838
# 997     No              316         14872           613          4760
# 998     No              305         14926           897          4572
# 999     No              168         14798           834          4937
#
# [1000 rows x 5 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Result  Initial Payment  Last Payment  Credit Score  House Number
# 0      yes              201         10018           250          3046
# 1      yes              205         10016           395          3044
# 2      yes              257         10129           109          3251
# 3      yes              246         10064           324          3137
# 4      yes              117         10115           496          3094
# ..     ...              ...           ...           ...           ...
# 995     No              413         14914           523          4683
# 996     No              359         14423           927          4838
# 997     No              316         14872           613          4760
# 998     No              305         14926           897          4572
# 999     No              168         14798           834          4937
#
# [1000 rows x 5 columns]>

# %%
df.describe(include='all')
# Out:
#        Result  Initial Payment  Last Payment  Credit Score  House Number
# count    1000       1000.00000    1000.00000   1000.000000   1000.000000
# unique      2              NaN           NaN           NaN           NaN
# top        No              NaN           NaN           NaN           NaN
# freq      521              NaN           NaN           NaN           NaN
# mean      NaN        294.34300   12465.88400    528.042000   4027.011000
# std       NaN        115.81539    1440.15617    259.796059    565.164179
# min       NaN        100.00000   10005.00000    100.000000   3003.000000
# 25%       NaN        195.00000   11201.50000    302.000000   3545.000000
# 50%       NaN        289.50000   12450.00000    516.500000   4041.500000
# 75%       NaN        398.00000   13678.25000    753.500000   4507.000000
# max       NaN        500.00000   14996.00000    997.000000   5000.000000

# %%
X = df.values[:, 1:5]
Y = df.values[:,0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3, random_state = 100)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_leaf=6)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=6)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['yes', 'yes', 'No', 'yes', 'No', 'yes', 'yes', 'yes', 'No', 'No',
#        'No', 'No', 'yes', 'No', 'No', 'yes', 'yes', 'No', 'yes', 'No',
#        'No', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'No', 'No',
#        'No', 'yes', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'No', 'No', 'yes', 'No', 'yes', 'No', 'No',
#        'yes', 'No', 'yes', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'yes',
#        'yes', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'yes', 'No', 'yes',
#        'No', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'yes', 'No',
#        'No', 'No', 'No', 'yes', 'No', 'yes', 'No', 'yes', 'yes', 'No',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'No', 'yes', 'yes', 'yes',
#        'yes', 'No', 'No', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'No',
#        'yes', 'yes', 'yes', 'yes', 'No', 'No', 'yes', 'yes', 'yes', 'No',
#        'No', 'No', 'No', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'No',
#        'No', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'No', 'yes', 'yes',
#        'No', 'No', 'yes', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'yes',
#        'No', 'yes', 'No', 'No', 'No', 'No', 'yes', 'No', 'No', 'No',
#        'yes', 'yes', 'No', 'yes', 'yes', 'No', 'yes', 'No', 'yes', 'No',
#        'No', 'yes', 'yes', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'No',
#        'No', 'No', 'No', 'yes', 'No', 'No', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'No', 'yes', 'No', 'yes', 'No', 'No', 'No', 'yes', 'yes',
#        'No', 'No', 'yes', 'yes', 'No', 'No', 'No', 'yes', 'yes', 'No',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'No',
#        'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'No', 'yes', 'yes',
#        'No', 'No', 'yes', 'No', 'yes', 'yes', 'yes', 'yes', 'No', 'No',
#        'No', 'No', 'yes', 'yes', 'No', 'yes', 'yes', 'No', 'yes', 'No',
#        'No', 'No', 'No', 'yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'No',
#        'yes', 'No', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'No', 'yes',
#        'No', 'yes', 'No', 'No', 'No', 'yes', 'yes', 'No', 'yes', 'yes',
#        'yes', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes',
#        'yes'], dtype=object)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9533333333333334

# %%
clf.score(X_train,y_train)
# Out:
# 0.9742857142857143

# %%
from sklearn import tree 
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[1] <= 12402.5\ngini = 0.498\nsamples = 700\nvalue = [374, 326]'),
#  Text(0.2565789473684211, 0.75, 'x[3] <= 4414.5\ngini = 0.181\nsamples = 328\nvalue = [33, 295]'),
#  Text(0.3782894736842105, 0.8333333333333333, 'True  '),
#  Text(0.13157894736842105, 0.5833333333333334, 'x[3] <= 4351.0\ngini = 0.033\nsamples = 237\nvalue = [4.0, 233.0]'),
#  Text(0.07894736842105263, 0.4166666666666667, 'x[1] <= 12323.5\ngini = 0.018\nsamples = 224\nvalue = [2, 222]'),
#  Text(0.05263157894736842, 0.25, 'x[2] <= 954.0\ngini = 0.009\nsamples = 218\nvalue = [1, 217]'),
#  Text(0.02631578947368421, 0.08333333333333333, 'gini = 0.0\nsamples = 209\nvalue = [0, 209]'),
#  Text(0.07894736842105263, 0.08333333333333333, 'gini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.10526315789473684, 0.25, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.18421052631578946, 0.4166666666666667, 'x[1] <= 11114.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.15789473684210525, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.21052631578947367, 0.25, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3815789473684211, 0.5833333333333334, 'x[1] <= 11892.0\ngini = 0.434\nsamples = 91\nvalue = [29.0, 62.0]'),
#  Text(0.3157894736842105, 0.4166666666666667, 'x[1] <= 11566.5\ngini = 0.187\nsamples = 67\nvalue = [7, 60]'),
#  Text(0.2631578947368421, 0.25, 'x[0] <= 444.5\ngini = 0.037\nsamples = 53\nvalue = [1, 52]'),
#  Text(0.23684210526315788, 0.08333333333333333, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.2894736842105263, 0.08333333333333333, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.3684210526315789, 0.25, 'x[2] <= 556.5\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.34210526315789475, 0.08333333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.39473684210526316, 0.08333333333333333, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4473684210526316, 0.4166666666666667, 'x[2] <= 352.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.42105263157894735, 0.25, 'gini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.47368421052631576, 0.25, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.743421052631579, 0.75, 'x[1] <= 13054.5\ngini = 0.153\nsamples = 372\nvalue = [341, 31]'),
#  Text(0.6217105263157895, 0.8333333333333333, '  False'),
#  Text(0.618421052631579, 0.5833333333333334, 'x[3] <= 3588.5\ngini = 0.439\nsamples = 80\nvalue = [54, 26]'),
#  Text(0.5526315789473685, 0.4166666666666667, 'x[3] <= 3442.0\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.5263157894736842, 0.25, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.5789473684210527, 0.25, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6842105263157895, 0.4166666666666667, 'x[3] <= 3966.5\ngini = 0.209\nsamples = 59\nvalue = [52, 7]'),
#  Text(0.631578947368421, 0.25, 'x[2] <= 390.0\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.6052631578947368, 0.08333333333333333, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6578947368421053, 0.08333333333333333, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.7368421052631579, 0.25, 'x[1] <= 12470.5\ngini = 0.046\nsamples = 42\nvalue = [41, 1]'),
#  Text(0.7105263157894737, 0.08333333333333333, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.7631578947368421, 0.08333333333333333, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.868421052631579, 0.5833333333333334, 'x[1] <= 13235.5\ngini = 0.034\nsamples = 292\nvalue = [287, 5]'),
#  Text(0.8157894736842105, 0.4166666666666667, 'x[3] <= 3613.5\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.7894736842105263, 0.25, 'gini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.8421052631578947, 0.25, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.9210526315789473, 0.4166666666666667, 'x[3] <= 3069.0\ngini = 0.015\nsamples = 266\nvalue = [264, 2]'),
#  Text(0.8947368421052632, 0.25, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.9473684210526315, 0.25, 'x[0] <= 108.5\ngini = 0.008\nsamples = 260\nvalue = [259, 1]'),
#  Text(0.9210526315789473, 0.08333333333333333, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9736842105263158, 0.08333333333333333, 'gini = 0.0\nsamples = 253\nvalue = [253, 0]')]
